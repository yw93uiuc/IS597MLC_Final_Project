# %%
# Importing necessary libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Load the preprocessed dataset
file_path = 'preprocessed_scorecard_data.csv'
data = pd.read_csv(file_path, low_memory=False)

# %%
data.describe()
# Out:
#              index        UNITID         OPEID        OPEID6         HCM2  \
# count  7703.000000  7.703000e+03  7.703000e+03   7703.000000  7703.000000
# mean   3851.000000  1.663052e+06  1.891630e+06  16293.906530     0.030637
# std    2223.808895  6.566910e+06  3.383134e+06  13883.577507     0.172344
# min       0.000000  1.006540e+05  1.002000e+05   1002.000000     0.000000
# 25%    1925.500000  1.742420e+05  3.440500e+05   3436.500000     0.000000
# 50%    3851.000000  2.304720e+05  1.054211e+06  10490.000000     0.000000
# 75%    5776.500000  4.476520e+05  2.811950e+06  25988.000000     0.000000
# max    7702.000000  4.841450e+07  8.209882e+07  42371.000000     1.000000
#
#            PREDDEG      CONTROL       LOCALE         HBCU          PBI  ...  \
# count  7703.000000  7703.000000  7282.000000  7282.000000  7282.000000  ...
# mean      1.799688     2.215371    19.620434     0.014282     0.013046  ...
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7703 entries, 0 to 7702
# Columns: 10198 entries, index to repayment_rate_high
# dtypes: bool(10075), float64(107), int64(9), object(7)
# memory usage: 81.2+ MB

# %%
# Checking for missing values
data.isnull().sum()
# Out:
# index                   0
# UNITID                  0
# OPEID                   0
# OPEID6                  0
# STABBR                  0
#                        ..
# CITY_Yukon              0
# CITY_Yuma               0
# CITY_Zanesville         0
# debt_to_income_ratio    0
# repayment_rate_high     0
# Length: 10198, dtype: int64

# %%
data.columns
# Out:
# Index(['index', 'UNITID', 'OPEID', 'OPEID6', 'STABBR', 'INSTURL', 'NPCURL',
#        'HCM2', 'PREDDEG', 'CONTROL',
#        ...
#        'CITY_Youngwood', 'CITY_Ypsilanti', 'CITY_Yuba City', 'CITY_Yucaipa',
#        'CITY_Yucca Valley', 'CITY_Yukon', 'CITY_Yuma', 'CITY_Zanesville',
#        'debt_to_income_ratio', 'repayment_rate_high'],
#       dtype='object', length=10198)

# %%
data.shape
# Out:
# (7703, 10198)

# %%
# Plot distributions of key numerical features
plt.figure(figsize=(12, 6))
for i, col in enumerate(['PCTFLOAN', 'MD_EARN_WNE_P10', 'GRAD_DEBT_MDN_SUPP']):
    plt.subplot(1, 3, i+1)
    sns.histplot(dataset[col], kde=True)
    plt.title(f'Distribution of {col}')

plt.tight_layout()
plt.show()
# Out:
# /Users/yuwakayama/opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /Users/yuwakayama/opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /Users/yuwakayama/opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
# Select only numeric columns for correlation matrix
numeric_cols = dataset.select_dtypes(include=['float64', 'int64']).columns

# Plot correlations between features
plt.figure(figsize=(10, 8))
corr_matrix = dataset[numeric_cols].corr()
sns.heatmap(corr_matrix, annot=True, fmt='.2f', cmap='coolwarm')
plt.title('Correlation Matrix')
plt.show()

# %%
# Box plots to examine the relationship between features and the target variable
plt.figure(figsize=(12, 6))
for i, col in enumerate(['PCTFLOAN', 'MD_EARN_WNE_P10', 'GRAD_DEBT_MDN_SUPP']):
    plt.subplot(1, 3, i+1)
    sns.boxplot(x='repayment_rate_high', y=col, data=dataset)
    plt.title(f'{col} vs Repayment Rate')

plt.tight_layout()
plt.show()
